# %%
pip install MetaTrader5
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import MetaTrader5 as mt
from datetime import datetime

# %%
mt.initialize()
# Out:
# True

# %%
login = 122516068
password = 'Sexparty69!'
server = 'Exness-MT5Trial7'

# %%
mt.login(login, password, server)
# Out:
# True

# %%
rates = mt.copy_rates_from("EURUSDm", mt.TIMEFRAME_D1, datetime.now(), 200)

# %%
rates
# Out:
# array([(1688256000, 1.09099, 1.09114, 1.09063, 1.09072,   837, 10, 0),
#        (1688342400, 1.09073, 1.09322, 1.08699, 1.09124, 37195,  8, 0),
#        (1688428800, 1.09125, 1.0916 , 1.08754, 1.0882 , 25103,  8, 0),
#        (1688515200, 1.08821, 1.09074, 1.08502, 1.08547, 39764,  8, 0),
#        (1688601600, 1.08548, 1.09002, 1.08333, 1.08893, 53643,  8, 0),
#        (1688688000, 1.08894, 1.09728, 1.08666, 1.09685, 49178,  8, 0),
#        (1688860800, 1.09601, 1.09678, 1.09589, 1.09665,  1009, 10, 0),
#        (1688947200, 1.09666, 1.10054, 1.0943 , 1.10049, 39439,  8, 0),
#        (1689033600, 1.1005 , 1.10265, 1.09766, 1.10132, 38278,  8, 0),
#        (1689120000, 1.10133, 1.11401, 1.10116, 1.114  , 48679,  8, 0),
#        (1689206400, 1.11402, 1.12276, 1.11295, 1.1223 , 46579,  8, 0),
#        (1689292800, 1.12231, 1.12444, 1.12039, 1.12281, 44780,  8, 0),
#        (1689465600, 1.12264, 1.12297, 1.12214, 1.12269,  1163, 10, 0),
# ...

# %%
account_info = mt.account_info()
account_info
# Out:
# AccountInfo(login=122516068, trade_mode=0, leverage=100, limit_orders=1024, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=997.36, credit=0.0, profit=0.0, equity=997.36, margin=0.0, margin_free=997.36, margin_level=0.0, margin_so_call=60.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Standard', server='Exness-MT5Trial7', currency='USD', company='Exness Technologies Ltd')

# %%
account_info.balance
# Out:
# 997.36

# %%
account_info.login
# Out:
# 122516068

# %%
num_symbols = mt.symbols_total()
num_symbols
# Out:
# 395

# %%
symbol_info = mt.symbols_get()
symbol_info
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=0, trade_calc_mode=0, trade_mode=0, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.0, trade_tick_value_profit=0.0, trade_tick_value_loss=0.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1e-08, volume_max=1e-08, volume_step=1e-08, volume_limit=0.0,
# ...

# %%
mt.symbol_info('EURUSDm')._asdict()
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1698253515,
#  'digits': 5,
#  'spread': 10,
#  'spread_float': True,
#  'ticks_bookdepth': 0,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 3,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1.0571,
#  'bidhigh': 1.06062,
#  'bidlow': 1.05655,
#  'ask': 1.0572,
#  'askhigh': 1.06072,
#  'asklow': 1.05665,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
# ...

# %%
import pandas as pd

# %%
ohlc = pd.DataFrame(mt.copy_rates_range('EURUSDm', mt.TIMEFRAME_H4, datetime(2023, 7,21), datetime.now()))
ohlc
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 0    1689883200  1.11315  1.11373  1.11257  1.11341         1486       8
# 1    1689897600  1.11341  1.11412  1.11294  1.11356         5317       8
# 2    1689912000  1.11357  1.11446  1.11246  1.11277         7535       8
# 3    1689926400  1.11277  1.11372  1.11169  1.11177         9223       8
# 4    1689940800  1.11178  1.11376  1.11074  1.11191        11456       8
# ..          ...      ...      ...      ...      ...          ...     ...
# 423  1698192000  1.05945  1.06046  1.05892  1.06016         4718       8
# 424  1698206400  1.06016  1.06062  1.05779  1.05868         5499       8
# 425  1698220800  1.05869  1.05963  1.05655  1.05723         7653       8
# 426  1698235200  1.05723  1.05952  1.05665  1.05827        13793       8
# 427  1698249600  1.05826  1.05855  1.05688  1.05741         3035       8
#
#      real_volume
# 0              0
# 1              0
# 2              0
# 3              0
# ...
